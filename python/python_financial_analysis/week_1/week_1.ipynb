# %% [markdown]
# # Import data
#
# Os comandos seguintes mostram como importar dados CSV para um notebook Jupyter usando o pacote <code>pandas</code>.

# %%
# Importação do pacote pandas
import pandas as pd

# %% [markdown]
# O primeiro conjunto de dados refere-se aos preços de ações do Facebook. O arquivo CSV que contém dos dados estálocalizado no diretório "Data".

# %%
fb = pd.read_csv('../data/facebook.csv', index_col=0)

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200

# %% [markdown]
# Em seguida, repetimos o procedimento para importar dados das ações da Microsoft:

# %%
ms = pd.read_csv('../data/microsoft.csv', index_col=0)

# %%
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100

# %%
print(ms.iloc[0,0])
# Out:
# 46.73

# %%
ms.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2018-01-30  93.300003  93.660004  92.099998  92.739998  92.306389  38635100
# 2018-01-31  93.750000  95.400002  93.510002  95.010002  94.565781  48756300
# 2018-02-01  94.790001  96.070000  93.580002  94.260002  93.819290  47227900
# 2018-02-02  93.639999  93.970001  91.500000  91.779999  91.350883  47867800
# 2018-02-05  90.559998  93.239998  88.000000  88.000000  87.588554  51031500

# %%
ms.index
# Out:
# Index(['2014-12-31', '2015-01-02', '2015-01-05', '2015-01-06', '2015-01-07',
#        '2015-01-08', '2015-01-09', '2015-01-12', '2015-01-13', '2015-01-14',
#        ...
#        '2018-01-23', '2018-01-24', '2018-01-25', '2018-01-26', '2018-01-29',
#        '2018-01-30', '2018-01-31', '2018-02-01', '2018-02-02', '2018-02-05'],
#       dtype='object', name='Date', length=780)

# %%
ms.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
fb.shape
# Out:
# (780, 6)

# %%
fb.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  780.000000  780.000000  780.000000  780.000000  780.000000
# mean    80.212705   81.285654   79.022397   80.264897   79.914215
# std     64.226121   65.048907   63.190963   64.198375   64.327846
# min     19.250000   19.500000   18.940001   19.139999   18.576082
# 25%     25.525000   26.085000   24.845000   25.475000   25.134512
# 50%     53.379999   54.034999   52.930000   53.420000   53.035403
# 75%    113.322502  115.779999  110.297499  113.702501  113.261238
# max    245.770004  249.270004  244.449997  246.850006  246.850006
#
#              Volume
# count  7.800000e+02
# mean   1.204453e+07
# std    8.221848e+06
# min    1.311200e+06
# 25%    7.215200e+06
# 50%    9.728700e+06
# 75%    1.408885e+07
# max    9.232320e+07

# %%
ms.describe()
# Out:
#              Open        High         Low       Close   Adj Close  \
# count  780.000000  780.000000  780.000000  780.000000  780.000000
# mean    58.912308   59.372308   58.465000   58.945397   56.931553
# std     12.852040   12.868060   12.802831   12.830350   13.670080
# min     40.340000   40.740002   39.720001   40.290001   37.267815
# 25%     47.894998   48.295000   47.535001   47.974998   44.792073
# 50%     56.150002   56.640001   55.700001   56.209999   53.775458
# 75%     67.892500   68.174997   67.447500   67.740000   66.565508
# max     95.139999   96.070000   93.720001   95.010002   94.565781
#
#              Volume
# count  7.800000e+02
# mean   2.978900e+07
# std    1.522319e+07
# min    7.425600e+06
# 25%    2.096685e+07
# 50%    2.623125e+07
# 75%    3.408020e+07
# max    1.691640e+08

# %%
fb.loc['2015-01-02', 'Close']
# Out:
# 20.129999

# %%
fb.iloc[1,3]
# Out:
# 20.129999

# %%
fb.loc['2015-01-01':'2015-12-31', 'Close']
# Out:
# Date
# 2015-01-02    20.129999
# 2015-01-05    19.790001
# 2015-01-06    19.190001
# 2015-01-07    19.139999
# 2015-01-08    19.860001
#                 ...
# 2015-12-24    33.169998
# 2015-12-28    33.139999
# 2015-12-29    33.680000
# 2015-12-30    33.389999
# 2015-12-31    32.959999
# Name: Close, Length: 252, dtype: float64

# %%
fb.loc['2015-01-01':'2015-12-31', 'Close'].plot()
fb.loc['2016-01-01':'2016-12-31', 'Close'].plot()
fb.loc['2017-01-01':'2017-12-31', 'Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# # DataFrame

# %%
# importação de pacotes
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fb = pd.read_csv('../data/facebook.csv', index_col=0)

# %%
fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200

# %%
fb.index = pd.to_datetime(fb.index, errors='coerce')

# %%
ms = pd.read_csv('../data/microsoft.csv', index_col=0)
ms.index = pd.to_datetime(ms.index, errors='coerce')
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100

# %%
ms.loc['2015-01-01':'2015-12-31', 'Close'].plot()
ms.loc['2016-01-01':'2016-12-31', 'Close'].plot()
ms.loc['2017-01-01':'2017-12-31', 'Close'].plot()
ms.loc['2018-01-01':'2018-12-31', 'Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ms_2016 = ms['2016-01-01':'2016-12-31']
ms_2016.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2016-01-04  54.320000  54.799999  53.389999  54.799999  51.927593  53778000
# 2016-01-05  54.930000  55.389999  54.540001  55.049999  52.164490  34079700
# 2016-01-06  54.320000  54.400002  53.639999  54.049999  51.216900  39518900
# 2016-01-07  52.700001  53.490002  52.070000  52.169998  49.435444  56564900
# 2016-01-08  52.369999  53.279999  52.150002  52.330002  49.587063  48754000

# %%
plt.figure(figsize=(10,8))
ms_2016['Close'].plot()
plt.show()

# %%
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100

# %%
ms['Returns'] = (ms['Close'].shift(-1) / ms['Close'] - 1.0) * 100
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100
#
#              Returns
# Date
# 2014-12-31  0.667378
# 2015-01-02 -0.919581
# 2015-01-05 -1.467731
# 2015-01-06  1.270532
# 2015-01-07  2.941813

# %%
ms.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-30  93.300003  93.660004  92.099998  92.739998  92.306389  38635100
# 2018-01-31  93.750000  95.400002  93.510002  95.010002  94.565781  48756300
# 2018-02-01  94.790001  96.070000  93.580002  94.260002  93.819290  47227900
# 2018-02-02  93.639999  93.970001  91.500000  91.779999  91.350883  47867800
# 2018-02-05  90.559998  93.239998  88.000000  88.000000  87.588554  51031500
#
#              Returns
# Date
# 2018-01-30  2.447708
# 2018-01-31 -0.789391
# 2018-02-01 -2.631024
# 2018-02-02 -4.118543
# 2018-02-05       NaN

# %% [markdown]
# # Creating new features and columns

# %%
# pacotes importados
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fb = pd.read_csv('../data/facebook.csv', index_col=0)
fb.index = pd.to_datetime(fb.index, errors='coerce')

fb.head()
# Out:
#                  Open       High        Low      Close  Adj Close   Volume
# Date
# 2014-12-31  20.400000  20.510000  19.990000  20.049999  19.459270  4157500
# 2015-01-02  20.129999  20.280001  19.809999  20.129999  19.536913  2842000
# 2015-01-05  20.129999  20.190001  19.700001  19.790001  19.206934  4948800
# 2015-01-06  19.820000  19.840000  19.170000  19.190001  18.624611  4944100
# 2015-01-07  19.330000  19.500000  19.080000  19.139999  18.576082  8045200

# %%
ms = pd.read_csv('../data/microsoft.csv', index_col=0)
ms.index = pd.to_datetime(ms.index, errors='coerce')

ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100

# %%
fb['PriceDiff'] = fb['Close'].shift(-1) - fb['Close']

# %%
ms['PriceDiff'] = ms['Close'].shift(-1) - ms['Close']

# %%
print(ms['PriceDiff'].loc['2015-01-05'])
# Out:
# -0.6799999999999997

# %%
fb['Return'] = fb['PriceDiff']/fb['Close']

# %%
ms['Return'] = ms['PriceDiff']/ms['Close']

# %%
print(ms['Return'].loc['2015-01-05'])
# Out:
# -0.014677314281143345

# %%
ms['Direction'] = [1 if ms['PriceDiff'].loc[ei] > 0 else 0 for ei in ms.index]

# %%
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2014-12-31  46.730000  47.439999  46.450001  46.450001  42.848763  21552500
# 2015-01-02  46.660000  47.419998  46.540001  46.759998  43.134731  27913900
# 2015-01-05  46.369999  46.730000  46.250000  46.330002  42.738068  39673900
# 2015-01-06  46.380001  46.750000  45.540001  45.650002  42.110783  36447900
# 2015-01-07  45.980000  46.459999  45.490002  46.230000  42.645817  29114100
#
#             PriceDiff    Return  Direction
# Date
# 2014-12-31   0.309997  0.006674          1
# 2015-01-02  -0.429996 -0.009196          0
# 2015-01-05  -0.680000 -0.014677          0
# 2015-01-06   0.579998  0.012705          1
# 2015-01-07   1.360000  0.029418          1

# %% [markdown]
# # Moving average
#
# Creating new column for moving average using <code>.rolling()</code>

# %%
fb['ma50'] = fb['Close'].rolling(50).mean()

#plot the moving average
plt.figure(figsize=(10, 8))
fb['ma50'].loc['2015-01-01':'2015-12-31'].plot(label='MA50')
fb['Close'].loc['2015-01-01':'2015-12-31'].plot(label='Close')
plt.legend()
plt.show()

# %%
# You can use .rolling() to calculate any numbers of days' Moving Average. This is your turn to calculate "60 days"
# moving average of Microsoft, rename it as "ma60". And follow the codes above in plotting a graph
ms['ma10'] = ms['Close'].rolling(10).mean()
ms['ma60'] = ms['Close'].rolling(60).mean()

#plot the moving average
plt.figure(figsize=(10, 8))
ms['ma10'].loc['2015-01-01':'2015-12-31'].plot(label='MA10')
ms['ma60'].loc['2015-01-01':'2015-12-31'].plot(label='MA60')
ms['Close'].loc['2015-01-01':'2015-12-31'].plot(label='Close')
plt.legend()
plt.show()

# %% [markdown]
# # Build a simple trading strategy

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## 1. Munging the stock data and add two columns - MA10 and MA50

# %%
#import FB's stock data, add two columns - MA10 and MA50
#use dropna to remove any "Not a Number" data
fb = pd.read_csv('../data/facebook.csv')# https://gadtmhkl.labs.coursera.org/notebooks/week%201/Build%20a%20simple%20trading%20strategy.ipynb#1.-Munging-the-stock-data-and-add-two-columns---MA10-and-MA50
fb['MA10'] = fb['Close'].rolling(10).mean()
fb['MA50'] = fb['Close'].rolling(50).mean()
fb = fb.dropna()
fb.head()
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 49  2015-03-13  22.559999  22.760000  22.250000  22.700001  22.116024
# 50  2015-03-16  22.879999  23.110001  22.730000  22.969999  22.379078
# 51  2015-03-17  22.920000  23.260000  22.760000  23.250000  22.651876
# 52  2015-03-18  23.250000  23.370001  22.660000  22.870001  22.281652
# 53  2015-03-19  22.950001  23.299999  22.780001  23.219999  22.622650
#
#       Volume    MA10     MA50
# 49   8982200  22.648  21.0174
# 50   5923900  22.685  21.0758
# 51   7497500  22.792  21.1382
# 52  10337600  22.836  21.1998
# 53   7768900  22.872  21.2804

# %% [markdown]
# ## 2. Add "Shares" column to make decisions base on the strategy

# %%
#Add a new column "Shares", if MA10>MA50, denote as 1 (long one share of stock), otherwise, denote as 0 (do nothing)

fb['Shares'] = [1 if fb.loc[ei, 'MA10']>fb.loc[ei, 'MA50'] else 0 for ei in fb.index]
fb.head()
# Out:
#           Date       Open       High        Low      Close  Adj Close  \
# 49  2015-03-13  22.559999  22.760000  22.250000  22.700001  22.116024
# 50  2015-03-16  22.879999  23.110001  22.730000  22.969999  22.379078
# 51  2015-03-17  22.920000  23.260000  22.760000  23.250000  22.651876
# 52  2015-03-18  23.250000  23.370001  22.660000  22.870001  22.281652
# 53  2015-03-19  22.950001  23.299999  22.780001  23.219999  22.622650
#
#       Volume    MA10     MA50  Shares
# 49   8982200  22.648  21.0174       1
# 50   5923900  22.685  21.0758       1
# 51   7497500  22.792  21.1382       1
# 52  10337600  22.836  21.1998       1
# 53   7768900  22.872  21.2804       1

# %%
fb.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume        MA10        MA50  Shares
# 775  14270800  235.692003  210.030001       1
# 776  11964400  237.800003  210.713801       1
# 777  12980600  239.406003  211.296601       1
# 778  17961600  239.747003  211.685401       1
# 779  28869000  237.748003  211.638401       1

# %%
#Add a new column "Profit" using List Comprehension, for any rows in fb, if Shares=1, the profit is calculated as the close price of 
#tomorrow - the close price of today. Otherwise the profit is 0.

#Plot a graph to show the Profit/Loss

fb['Close1'] = fb['Close'].shift(-1)
fb['Profit'] = [fb.loc[ei, 'Close1'] - fb.loc[ei, 'Close'] if fb.loc[ei, 'Shares']==1 else 0 for ei in fb.index]
fb['Profit'].plot()
plt.axhline(y=0, color='red')

# %% [markdown]
# ## 3. Use .cumsum() to display our model's performance if we follow the strategy

# %%
#Use .cumsum() to calculate the accumulated wealth over the period

fb['wealth'] = fb['Profit'].cumsum()
fb.tail()
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 775  2018-01-30  241.110001  246.419998  238.410004  242.720001  242.720001
# 776  2018-01-31  245.770004  249.270004  244.449997  245.800003  245.800003
# 777  2018-02-01  238.520004  246.899994  238.059998  240.500000  240.500000
# 778  2018-02-02  237.000000  237.970001  231.169998  233.520004  233.520004
# 779  2018-02-05  227.000000  233.229996  205.000000  213.699997  213.699997
#
#        Volume        MA10        MA50  Shares      Close1     Profit  \
# 775  14270800  235.692003  210.030001       1  245.800003   3.080002
# 776  11964400  237.800003  210.713801       1  240.500000  -5.300003
# 777  12980600  239.406003  211.296601       1  233.520004  -6.979996
# 778  17961600  239.747003  211.685401       1  213.699997 -19.820007
# 779  28869000  237.748003  211.638401       1         NaN        NaN
#
#          wealth
# 775  177.820011
# 776  172.520008
# 777  165.540012
# 778  145.720005
# ...

# %%
#plot the wealth to show the growth of profit over the period

fb['wealth'].plot()
plt.title('Total money you win is {}'.format(fb.loc[fb.index[-2], 'wealth']))
# Out:
# Text(0.5, 1.0, 'Total money you win is 145.72000500000001')

# %% [markdown]
# ## You can create your own simple trading strategy by copying the codes above and modify the codes accordingly using the data of Microsoft (microsoft.csv).

# %% [markdown]
# ### 1. Munging the stock data and add two columns - MA10 and MA50

# %%
ms = pd.read_csv('../data/microsoft.csv', index_col=0)
ms.index = pd.to_datetime(ms.index)
ms['MA10'] = ms['Close'].rolling(10).mean()
ms['MA50'] = ms['Close'].rolling(50).mean()
ms = ms.dropna()
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2015-03-13  40.700001  41.470001  40.610001  41.380001  38.443489  58007700
# 2015-03-16  41.470001  41.639999  41.279999  41.560001  38.610714  35273500
# 2015-03-17  41.369999  41.830002  41.150002  41.700001  38.740784  31587200
# 2015-03-18  41.430000  42.830002  41.330002  42.500000  39.484009  43971800
# 2015-03-19  42.259998  42.590000  42.220001  42.290001  39.288918  33879100
#
#               MA10     MA50
# Date
# 2015-03-13  42.495  44.0034
# 2015-03-16  42.263  43.9056
# 2015-03-17  42.105  43.8044
# 2015-03-18  42.049  43.7278
# 2015-03-19  41.967  43.6606

# %% [markdown]
# ### 2. Add "Shares" column to make decisions base on the strategy

# %%
ms['Shares'] = [1 if ms.loc[ei, 'MA10']>ms.loc[ei,'MA50'] else 0 for ei in ms.index]
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2015-03-13  40.700001  41.470001  40.610001  41.380001  38.443489  58007700
# 2015-03-16  41.470001  41.639999  41.279999  41.560001  38.610714  35273500
# 2015-03-17  41.369999  41.830002  41.150002  41.700001  38.740784  31587200
# 2015-03-18  41.430000  42.830002  41.330002  42.500000  39.484009  43971800
# 2015-03-19  42.259998  42.590000  42.220001  42.290001  39.288918  33879100
#
#               MA10     MA50  Shares
# Date
# 2015-03-13  42.495  44.0034       0
# 2015-03-16  42.263  43.9056       0
# 2015-03-17  42.105  43.8044       0
# 2015-03-18  42.049  43.7278       0
# 2015-03-19  41.967  43.6606       0

# %%
ms.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-30  93.300003  93.660004  92.099998  92.739998  92.306389  38635100
# 2018-01-31  93.750000  95.400002  93.510002  95.010002  94.565781  48756300
# 2018-02-01  94.790001  96.070000  93.580002  94.260002  93.819290  47227900
# 2018-02-02  93.639999  93.970001  91.500000  91.779999  91.350883  47867800
# 2018-02-05  90.559998  93.239998  88.000000  88.000000  87.588554  51031500
#
#               MA10     MA50  Shares
# Date
# 2018-01-30  91.862  86.5244       1
# 2018-01-31  92.349  86.7606       1
# 2018-02-01  92.765  86.9978       1
# 2018-02-02  92.943  87.1828       1
# 2018-02-05  92.582  87.2684       1

# %%
ms['Close1'] = ms['Close'].shift(-1)
ms['Profit'] = [ms.loc[ei, 'Close1']-ms.loc[ei, 'Close'] if ms.loc[ei, 'Shares']==1 else 0 for ei in ms.index]
ms['Profit'].plot()
plt.axhline(y = 0, color='red')

# %% [markdown]
# ### 3. Use .cumsum() to display our model's performance if we follow the strategy¶

# %%
#Use .cumsum() to calculate the accumulated wealth over the period

ms['wealth'] = ms['Profit'].cumsum()
ms.tail()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-30  93.300003  93.660004  92.099998  92.739998  92.306389  38635100
# 2018-01-31  93.750000  95.400002  93.510002  95.010002  94.565781  48756300
# 2018-02-01  94.790001  96.070000  93.580002  94.260002  93.819290  47227900
# 2018-02-02  93.639999  93.970001  91.500000  91.779999  91.350883  47867800
# 2018-02-05  90.559998  93.239998  88.000000  88.000000  87.588554  51031500
#
#               MA10     MA50  Shares     Close1    Profit     wealth
# Date
# 2018-01-30  91.862  86.5244       1  95.010002  2.270004  30.540009
# 2018-01-31  92.349  86.7606       1  94.260002 -0.750000  29.790009
# 2018-02-01  92.765  86.9978       1  91.779999 -2.480003  27.310006
# 2018-02-02  92.943  87.1828       1  88.000000 -3.779999  23.530007
# 2018-02-05  92.582  87.2684       1        NaN       NaN        NaN

# %%
ms.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2015-03-13  40.700001  41.470001  40.610001  41.380001  38.443489  58007700
# 2015-03-16  41.470001  41.639999  41.279999  41.560001  38.610714  35273500
# 2015-03-17  41.369999  41.830002  41.150002  41.700001  38.740784  31587200
# 2015-03-18  41.430000  42.830002  41.330002  42.500000  39.484009  43971800
# 2015-03-19  42.259998  42.590000  42.220001  42.290001  39.288918  33879100
#
#               MA10     MA50  Shares     Close1  Profit  wealth
# Date
# 2015-03-13  42.495  44.0034       0  41.560001     0.0     0.0
# 2015-03-16  42.263  43.9056       0  41.700001     0.0     0.0
# 2015-03-17  42.105  43.8044       0  42.500000     0.0     0.0
# 2015-03-18  42.049  43.7278       0  42.290001     0.0     0.0
# 2015-03-19  41.967  43.6606       0  42.880001     0.0     0.0

# %%
#plot the wealth to show the growth of profit over the period

ms['wealth'].plot()
plt.title('Total money you win is {}'.format(ms.loc[ms.index[-2], 'wealth']))
# Out:
# Text(0.5, 1.0, 'Total money you win is 23.53000699999999')
